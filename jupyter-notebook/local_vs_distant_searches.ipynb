# %%
import sys
sys.path.append("/home/mariacst/exoplanets/exoplanets/python/sensitivity/non_linear")

import mock_generation, imp
imp.reload(mock_generation)

from mock_generation import mock_population_all
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
seed = 100                                                            
np.random.seed(seed)   

nBDs=100
sigma=0.
relT=0.

(robs, sigmarobs, Tobs, sigmaTobs, Mobs,                                   
sigmaMobs, Aobs, sigmaAobs) = mock_population_all(nBDs, relT, sigma, sigma, sigma, 0., 1., 1., Tmin=0., v=100.)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 7))

ax.scatter(robs, Tobs)
